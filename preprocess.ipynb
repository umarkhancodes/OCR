# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('plate2.jpeg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

# %%
plt.imshow(thresh,cmap="gray")
plt.show()

# %%
kernel = np.ones((3,3),np.uint8)
opening = cv2.morphologyEx(thresh,cv2.MORPH_OPEN,kernel, iterations = 1)

# %%
plt.imshow(opening,cmap="gray")
plt.show()

# %%
edged = cv2.Canny(opening, 30, 200)
plt.imshow(edged)

# %%
ctrs, hier = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
plt.imshow(cv2.drawContours(img, ctrs, -1, (0, 255, 0), 3))

# %%
sorted_ctrs = sorted(ctrs, key=lambda ctr: cv2.boundingRect(ctr)[0])

# %%
# n=1
# for i, ctr in enumerate(sorted_ctrs):

    
#         # Get bounding box
#     x, y, w, h = cv2.boundingRect(ctr)
#     print(x,y,w,h)
#     # Getting ROI
#     area=w*h
#     if (area>1300):
#         roi = img[y:y+h, x:x+w]
#         n1=".jpg"
#         n2=str(n)
#         n3=n2+n1
#         n=n+1
#         # show ROI
#         cv2.imwrite(n3, roi)

# %%
for i, ctr in enumerate(sorted_ctrs):
    x, y, w, h = cv2.boundingRect(ctr)
    area=w*h
    if (area>1300):
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(img)

# %%
images=[]
for i, ctr in enumerate(sorted_ctrs):

    
        # Get bounding box
    x, y, w, h = cv2.boundingRect(ctr)
    print(x,y,w,h)
    # Getting ROI
    area=w*h
    if (area>1300):
        roi = img[y:y+h, x:x+w]
        images.append(roi)
# Out:
# 0 183 259 11
# 0 104 1 2
# 0 99 1 1
# 0 96 1 1
# 0 71 1 1
# 0 64 31 64
# 0 0 259 7
# 1 80 1 1
# 1 69 1 1
# 34 178 1 1
# 34 151 5 26
# 41 151 20 27
# 41 64 26 64
# 42 175 1 1
# 54 157 1 1
# 61 151 17 29
# 68 179 1 1
# 70 179 1 1
# 82 178 1 2
# 83 150 24 28
# 97 174 2 1
# 99 177 1 1
# 99 14 4 27
# 104 168 1 1
# 105 7 6 1
# 106 150 25 28
# 112 7 8 1
# 113 14 21 27
# 115 88 12 14
# 120 40 3 1
# 123 6 2 2
# 125 176 1 1
# 126 166 1 1
# 127 178 1 1
# 130 7 1 1
# 132 150 24 27
# 134 6 4 2
# 140 6 4 2
# 141 13 20 26
# 147 7 1 1
# 149 172 1 2
# 151 40 1 1
# 151 7 1 1
# 152 177 1 1
# 156 125 1 1
# 156 63 26 62
# 157 18 2 1
# 157 6 6 1
# 159 150 19 29
# 164 126 1 1
# 166 73 2 1
# 170 73 1 1
# 180 150 22 26
# 194 79 1 1
# 194 63 26 62
# 198 126 2 1
# 204 149 19 28
# 232 63 27 62

# %%
a=sorted_ctrs[0]

# %%
x, y, w, h = cv2.boundingRect(a)
print(x,y,w,h)
# Out:
# 0 182 259 5

# %%
cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(img)

# %%
roi = img[y:y+h, x:x+w]
plt.imshow(roi)

# %%
gray2 = cv2.cvtColor(roi,cv2.COLOR_BGR2GRAY)
ret2, thresh2 = cv2.threshold(gray2,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

plt.imshow(thresh2,cmap="gray")
# kernel = np.ones((3,3),np.uint8)
# opening = cv2.morphologyEx(thresh2,cv2.MORPH_OPEN,kernel, iterations = 1)

# edged2 = cv2.Canny(opening, 30, 200)
# plt.imshow(edged2)


# plt.imshow(edged2)

# %%
edged2 = cv2.Canny(thresh2, 30, 200)
plt.imshow(edged2)

# %%
ctrs2, hier2 = cv2.findContours(edged2.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
plt.imshow(cv2.drawContours(roi, ctrs2, -1, (0, 255, 0), 3))
sorted_ctrs2 = sorted(ctrs2, key=lambda ctr: cv2.boundingRect(ctr)[0])

# %%
for i, ctr in enumerate(sorted_ctrs2):
    x, y, w, h = cv2.boundingRect(ctr)
    area=w*h
    if (area>1300):
        cv2.rectangle(roi,(x,y),(x+w,y+h),(255,0,0),2)

# %%
plt.imshow(roi)

# %%
images=[]
for i, ctr in enumerate(sorted_ctrs):

    
        # Get bounding box
    x, y, w, h = cv2.boundingRect(ctr)
    print(x,y,w,h)
    # Getting ROI
    area=w*h
    if (area>1300):
        roi = img[y:y+h, x:x+w]
        images.append(roi)
